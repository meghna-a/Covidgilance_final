# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Input folder
df1 = pd.read_csv(r'C:\Users\meghn\Desktop\Covidgilance_Final\Covidgilance_final\Step0_dataCollection\covid_cases_deaths.csv')
df2 = pd.read_csv(r'C:\Users\meghn\Desktop\Covidgilance_Final\Covidgilance_final\Step0_dataCollection\gender_age.csv')

# %%
df1
# Out:
#              date      county       state     fips  cases  deaths
# 0      2020-01-21   Snohomish  Washington  53061.0      1       0
# 1      2020-01-22   Snohomish  Washington  53061.0      1       0
# 2      2020-01-23   Snohomish  Washington  53061.0      1       0
# 3      2020-01-24        Cook    Illinois  17031.0      1       0
# 4      2020-01-24   Snohomish  Washington  53061.0      1       0
# ...           ...         ...         ...      ...    ...     ...
# 70213  2020-04-18    Sublette     Wyoming  56035.0      1       0
# 70214  2020-04-18  Sweetwater     Wyoming  56037.0     10       0
# 70215  2020-04-18       Teton     Wyoming  56039.0     62       0
# 70216  2020-04-18       Uinta     Wyoming  56041.0      6       0
# 70217  2020-04-18    Washakie     Wyoming  56043.0      4       0
#
# [70218 rows x 6 columns]

# %%
df1.isnull()
# Out:
#         date  county  state   fips  cases  deaths
# 0      False   False  False  False  False   False
# 1      False   False  False  False  False   False
# 2      False   False  False  False  False   False
# 3      False   False  False  False  False   False
# 4      False   False  False  False  False   False
# ...      ...     ...    ...    ...    ...     ...
# 70213  False   False  False  False  False   False
# 70214  False   False  False  False  False   False
# 70215  False   False  False  False  False   False
# 70216  False   False  False  False  False   False
# 70217  False   False  False  False  False   False
#
# [70218 rows x 6 columns]

# %%
sns.heatmap(df1.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')

# %%
df2
# Out:
#          state   county  AGEGRP  tot_pop_per_agegrp  TOT_MALE  TOT_FEMALE  \
# 0      Alabama  Autauga       0               55601     26995       28606
# 1      Alabama  Autauga       1                3364      1728        1636
# 2      Alabama  Autauga       2                3423      1779        1644
# 3      Alabama  Autauga       3                3882      1977        1905
# 4      Alabama  Autauga       4                3755      1913        1842
# ...        ...      ...     ...                 ...       ...         ...
# 59712  Wyoming   Weston      14                 473       267         206
# 59713  Wyoming   Weston      15                 336       168         168
# 59714  Wyoming   Weston      16                 224       104         120
# 59715  Wyoming   Weston      17                 196        88         108
# 59716  Wyoming   Weston      18                 200        69         131
#
#                    AGEGRPDEF  TOT_POP  percent_agegrp  percent_male  \
# ...

# %%
sns.heatmap(df2.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')

# %%
df = pd.merge(df1,df2, on = ['state', 'county', 'fips'], how = 'left')

# %%
df
# Out:
#                date     county       state     fips  cases  deaths  AGEGRP  \
# 0        2020-01-21  Snohomish  Washington  53061.0      1       0     0.0
# 1        2020-01-21  Snohomish  Washington  53061.0      1       0     1.0
# 2        2020-01-21  Snohomish  Washington  53061.0      1       0     2.0
# 3        2020-01-21  Snohomish  Washington  53061.0      1       0     3.0
# 4        2020-01-21  Snohomish  Washington  53061.0      1       0     4.0
# ...             ...        ...         ...      ...    ...     ...     ...
# 1314313  2020-04-18   Washakie     Wyoming  56043.0      4       0    14.0
# 1314314  2020-04-18   Washakie     Wyoming  56043.0      4       0    15.0
# 1314315  2020-04-18   Washakie     Wyoming  56043.0      4       0    16.0
# 1314316  2020-04-18   Washakie     Wyoming  56043.0      4       0    17.0
# 1314317  2020-04-18   Washakie     Wyoming  56043.0      4       0    18.0
#
# ...

# %%
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
