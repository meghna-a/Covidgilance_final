# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Input folder
df1 = pd.read_csv(r'C:\Users\meghn\Desktop\Covidgilance_Final\Covidgilance_final\Step0_dataCollection\April_11_data.csv')
df2 = pd.read_csv(r'C:\Users\meghn\Desktop\Covidgilance_Final\Covidgilance_final\Step0_dataCollection\gender_age.csv')
df3 = pd.read_csv(r'C:\Users\meghn\Desktop\Covidgilance_Final\Covidgilance_final\Step0_dataCollection\county_zipcode_true_ave.csv')

# %%
df1
# Out:
#        County           State    FIPS  Cases  Deaths
# 0     Autauga         Alabama  1001.0     19       1
# 1     Baldwin         Alabama  1003.0     66       1
# 2     Barbour         Alabama  1005.0     10       0
# 3        Bibb         Alabama  1007.0     13       0
# 4      Blount         Alabama  1009.0     12       0
# ...       ...             ...     ...    ...     ...
# 2655  Unknown            Utah     NaN     22       7
# 2656  Unknown         Vermont     NaN     11       0
# 2657  Unknown  Virgin Islands     NaN     51       1
# 2658  Unknown        Virginia     NaN      0      58
# 2659  Unknown      Washington     NaN    583       0
#
# [2660 rows x 5 columns]

# %%
df1.rename(columns ={'FIPS': 'fips', 'County': 'county'}, inplace = True)

# %%
df2
# Out:
#          state   county  AGEGRP  tot_pop_per_agegrp  TOT_MALE  TOT_FEMALE  \
# 0      Alabama  Autauga       0               55601     26995       28606
# 1      Alabama  Autauga       1                3364      1728        1636
# 2      Alabama  Autauga       2                3423      1779        1644
# 3      Alabama  Autauga       3                3882      1977        1905
# 4      Alabama  Autauga       4                3755      1913        1842
# ...        ...      ...     ...                 ...       ...         ...
# 59712  Wyoming   Weston      14                 473       267         206
# 59713  Wyoming   Weston      15                 336       168         168
# 59714  Wyoming   Weston      16                 224       104         120
# 59715  Wyoming   Weston      17                 196        88         108
# 59716  Wyoming   Weston      18                 200        69         131
#
#                    AGEGRPDEF  TOT_POP  percent_agegrp  percent_male  \
# 0           Total Population    55601      100.000000     48.551285
# 1           Age 0 to 4 years    55601        6.050251      3.107858
# 2           Age 5 to 9 years    55601        6.156364      3.199583
# 3         Age 10 to 14 years    55601        6.981889      3.555691
# 4         Age 15 to 19 years    55601        6.753476      3.440586
# ...                      ...      ...             ...           ...
# 59712     Age 65 to 69 years     6967        6.789149      3.832353
# 59713     Age 70 to 74 years     6967        4.822736      2.411368
# 59714     Age 75 to 79 years     6967        3.215157      1.492752
# 59715     Age 80 to 84 years     6967        2.813263      1.263097
# 59716  Age 85 years or older     6967        2.870676      0.990383
#
#        percent_female state_abbr      ssa     fips
# 0           51.448715         AL   1000.0   1001.0
# 1            2.942393         AL   1000.0   1001.0
# 2            2.956781         AL   1000.0   1001.0
# 3            3.426197         AL   1000.0   1001.0
# 4            3.312890         AL   1000.0   1001.0
# ...               ...        ...      ...      ...
# 59712        2.956796         WY  53220.0  56045.0
# 59713        2.411368         WY  53220.0  56045.0
# 59714        1.722406         WY  53220.0  56045.0
# 59715        1.550165         WY  53220.0  56045.0
# 59716        1.880293         WY  53220.0  56045.0
#
# [59717 rows x 14 columns]

# %%
df3
# Out:
#       county_fips county_name state_id  population  pop_area_est  density
# 0            1001     Autauga       AL       57046       1512.03    37.73
# 1            1003     Baldwin       AL      207694       4077.05    50.94
# 2            1005     Barbour       AL       25278       1821.81    13.88
# 3            1007        Bibb       AL       22859       1415.86    16.14
# 4            1009      Blount       AL       45030       1311.39    34.34
# ...           ...         ...      ...         ...           ...      ...
# 3129        56037  Sweetwater       WY       44117       6322.20     6.98
# 3130        56039       Teton       WY       22196       6268.00     3.54
# 3131        56041       Uinta       WY       20630       3833.92     5.38
# 3132        56043    Washakie       WY        8295       3262.25     2.54
# 3133        56045      Weston       WY        7263       6741.91     1.08
#
# [3134 rows x 6 columns]

# %%
df3.rename(columns = {'county_fips':'fips','county_name':'county','state_id':'state' }, inplace = True)

# %%
df3.head()
# Out:
#    fips   county state  population  pop_area_est  density
# 0  1001  Autauga    AL       57046       1512.03    37.73
# 1  1003  Baldwin    AL      207694       4077.05    50.94
# 2  1005  Barbour    AL       25278       1821.81    13.88
# 3  1007     Bibb    AL       22859       1415.86    16.14
# 4  1009   Blount    AL       45030       1311.39    34.34

# %%
df = pd.merge(df1,df3, on = ['fips','county'], how = 'inner')

# %%
df_final = pd.merge(df,df2, on = ['fips','county'], how = 'inner')

# %%
df_final
# Out:
#          county    State     fips  Cases  Deaths state_x  population  \
# 0       Autauga  Alabama   1001.0     19       1      AL       57046
# 1       Autauga  Alabama   1001.0     19       1      AL       57046
# 2       Autauga  Alabama   1001.0     19       1      AL       57046
# 3       Autauga  Alabama   1001.0     19       1      AL       57046
# 4       Autauga  Alabama   1001.0     19       1      AL       57046
# ...         ...      ...      ...    ...     ...     ...         ...
# 49015  Washakie  Wyoming  56043.0      4       0      WY        8295
# 49016  Washakie  Wyoming  56043.0      4       0      WY        8295
# 49017  Washakie  Wyoming  56043.0      4       0      WY        8295
# 49018  Washakie  Wyoming  56043.0      4       0      WY        8295
# 49019  Washakie  Wyoming  56043.0      4       0      WY        8295
#
#        pop_area_est  density  state_y  ...  tot_pop_per_agegrp  TOT_MALE  \
# 0           1512.03    37.73  Alabama  ...               55601     26995
# 1           1512.03    37.73  Alabama  ...                3364      1728
# 2           1512.03    37.73  Alabama  ...                3423      1779
# 3           1512.03    37.73  Alabama  ...                3882      1977
# 4           1512.03    37.73  Alabama  ...                3755      1913
# ...             ...      ...      ...  ...                 ...       ...
# 49015       3262.25     2.54  Wyoming  ...                 517       268
# 49016       3262.25     2.54  Wyoming  ...                 420       204
# 49017       3262.25     2.54  Wyoming  ...                 321       175
# 49018       3262.25     2.54  Wyoming  ...                 210        84
# 49019       3262.25     2.54  Wyoming  ...                 242        97
#
#        TOT_FEMALE              AGEGRPDEF TOT_POP  percent_agegrp  \
# 0           28606       Total Population   55601      100.000000
# 1            1636       Age 0 to 4 years   55601        6.050251
# 2            1644       Age 5 to 9 years   55601        6.156364
# 3            1905     Age 10 to 14 years   55601        6.981889
# 4            1842     Age 15 to 19 years   55601        6.753476
# ...           ...                    ...     ...             ...
# 49015         249     Age 65 to 69 years    7885        6.556753
# 49016         216     Age 70 to 74 years    7885        5.326569
# 49017         146     Age 75 to 79 years    7885        4.071021
# 49018         126     Age 80 to 84 years    7885        2.663285
# 49019         145  Age 85 years or older    7885        3.069119
#
#        percent_male  percent_female  state_abbr      ssa
# 0         48.551285       51.448715          AL   1000.0
# 1          3.107858        2.942393          AL   1000.0
# 2          3.199583        2.956781          AL   1000.0
# 3          3.555691        3.426197          AL   1000.0
# 4          3.440586        3.312890          AL   1000.0
# ...             ...             ...         ...      ...
# 49015      3.398859        3.157895          WY  53210.0
# 49016      2.587191        2.739379          WY  53210.0
# 49017      2.219404        1.851617          WY  53210.0
# 49018      1.065314        1.597971          WY  53210.0
# 49019      1.230184        1.838935          WY  53210.0
#
# [49020 rows x 21 columns]

# %%
sns.heatmap(df_final.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')

# %%
df_final.drop(columns = ['state_y','state_abbr'], inplace = True)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49020 entries, 0 to 49019
# Data columns (total 19 columns):
# county                49020 non-null object
# State                 49020 non-null object
# fips                  49020 non-null float64
# Cases                 49020 non-null int64
# Deaths                49020 non-null int64
# state_x               49020 non-null object
# population            49020 non-null int64
# pop_area_est          49020 non-null float64
# density               49020 non-null float64
# AGEGRP                49020 non-null int64
# tot_pop_per_agegrp    49020 non-null int64
# TOT_MALE              49020 non-null int64
# TOT_FEMALE            49020 non-null int64
# AGEGRPDEF             49020 non-null object
# TOT_POP               49020 non-null int64
# percent_agegrp        49020 non-null float64
# percent_male          49020 non-null float64
# percent_female        49020 non-null float64
# ssa                   49020 non-null float64
# dtypes: float64(7), int64(8), object(4)
# memory usage: 7.5+ MB

# %%
# sns.lmplot(x= 'population', y = 'cases', data = df_final)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_final.drop(['Cases','county','state_x','AGEGRPDEF','TOT_POP','State','ssa'],axis=1)
y = df_final['Cases']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state = 42, stratify = y)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.preprocessing import MinMaxScaler
X_scaler = StandardScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# from sklearn.svm import SVC

# %%
# svc_model = SVC(kernel = 'linear')
# svc_model.fit(X_train,y_train)

# %%
# model_svc.score(X_train_scaled, y_train)
# model_svc.score(X_test_scaled, y_test)

# %%
# print(f"Training Data Score: {model_svc.score(X_train_scaled, y_train)}")
# print(f"Testing Data Score: {model_svc.score(X_test_scaled, y_test)}")

# %%
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression()
model_lr.fit(X_train_scaled, y_train)
# Out:
# C:\Users\meghn\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\meghn\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model_lr.score(X_train_scaled, y_train)
model_lr.score(X_test_scaled, y_test)
# Out:
# 0.12933496532027744

# %%
print(f"Training Data Score: {model_lr.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model_lr.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.13117095063239495
# Testing Data Score: 0.12933496532027744

# %%
# from sklearn.model_selection import GridSearchCV
# param_grid = {'C':[1,5,10], 'penalty':['l2']}
# grid_lr = GridSearchCV(model_lr, param_grid)

# %%
# grid_lr.fit(X_train_scaled, y_train)

# %%
# print(grid_lr.best_params_)
# print(grid_lr.best_score_)
